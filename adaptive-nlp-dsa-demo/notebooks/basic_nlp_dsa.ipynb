# %% [markdown]
# # Basic NLP Exercise for Students with DSA
#
# In this notebook, we use spaCy to extract words from a simple sentence.

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
text = "Björk sings beautifully."
doc = nlp(text)
for token in doc:
    print(f"{token.text} → {token.pos_}")
